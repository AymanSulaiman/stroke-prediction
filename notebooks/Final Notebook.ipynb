# %% [markdown]
# # Importing the required files

# %%
import os
import pandas as pd
import numpy as np
import joblib
import warnings
import pickle
warnings.filterwarnings('ignore')
from lazypredict.Supervised import LazyClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Loading the stroke dataset from a local source

# %%
df = pd.read_csv(os.path.join('..','data','healthcare-dataset-stroke-data.csv'))
df = df.dropna()
df = df.drop('id',axis=1)
df
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male 67.00             0              1          Yes        Private
# 2       Male 80.00             0              1          Yes        Private
# 3     Female 49.00             0              0          Yes        Private
# 4     Female 79.00             1              0          Yes  Self-employed
# 5       Male 81.00             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 5104  Female 13.00             0              0           No       children
# 5106  Female 81.00             0              0          Yes  Self-employed
# 5107  Female 35.00             0              0          Yes  Self-employed
# 5108    Male 51.00             0              0          Yes        Private
# 5109  Female 44.00             0              0          Yes       Govt_job
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0             Urban             228.69 36.60  formerly smoked       1
# 2             Rural             105.92 32.50     never smoked       1
# 3             Urban             171.23 34.40           smokes       1
# 4             Rural             174.12 24.00     never smoked       1
# 5             Urban             186.21 29.00  formerly smoked       1
# ...             ...                ...   ...              ...     ...
# 5104          Rural             103.08 18.60          Unknown       0
# 5106          Urban             125.20 40.00     never smoked       0
# 5107          Rural              82.99 30.60     never smoked       0
# 5108          Rural             166.29 25.60  formerly smoked       0
# 5109          Urban              85.28 26.20          Unknown       0
#
# [4909 rows x 11 columns]

# %% [markdown]
# # Used a label encodeder to give categorical features numerical values

# %%
le = LabelEncoder()
list_of_cat_feat = ['gender','ever_married','work_type','Residence_type','smoking_status']
for i in list_of_cat_feat:
    df[f'{i}_encoded'] = le.fit_transform(df[f"{i}"])
    
df
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male 67.00             0              1          Yes        Private
# 2       Male 80.00             0              1          Yes        Private
# 3     Female 49.00             0              0          Yes        Private
# 4     Female 79.00             1              0          Yes  Self-employed
# 5       Male 81.00             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 5104  Female 13.00             0              0           No       children
# 5106  Female 81.00             0              0          Yes  Self-employed
# 5107  Female 35.00             0              0          Yes  Self-employed
# 5108    Male 51.00             0              0          Yes        Private
# 5109  Female 44.00             0              0          Yes       Govt_job
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke  \
# 0             Urban             228.69 36.60  formerly smoked       1
# 2             Rural             105.92 32.50     never smoked       1
# 3             Urban             171.23 34.40           smokes       1
# 4             Rural             174.12 24.00     never smoked       1
# 5             Urban             186.21 29.00  formerly smoked       1
# ...             ...                ...   ...              ...     ...
# 5104          Rural             103.08 18.60          Unknown       0
# 5106          Urban             125.20 40.00     never smoked       0
# 5107          Rural              82.99 30.60     never smoked       0
# 5108          Rural             166.29 25.60  formerly smoked       0
# 5109          Urban              85.28 26.20          Unknown       0
#
#       gender_encoded  ever_married_encoded  work_type_encoded  \
# 0                  1                     1                  2
# 2                  1                     1                  2
# 3                  0                     1                  2
# 4                  0                     1                  3
# 5                  1                     1                  2
# ...              ...                   ...                ...
# 5104               0                     0                  4
# 5106               0                     1                  3
# 5107               0                     1                  3
# 5108               1                     1                  2
# 5109               0                     1                  0
#
#       Residence_type_encoded  smoking_status_encoded
# 0                          1                       1
# 2                          0                       2
# 3                          1                       3
# 4                          0                       2
# 5                          1                       1
# ...                      ...                     ...
# 5104                       0                       0
# 5106                       1                       2
# 5107                       0                       2
# 5108                       0                       1
# 5109                       1                       0
#
# [4909 rows x 16 columns]

# %% [markdown]
# # Droped the categorical values

# %%
df_cat = df.drop(list_of_cat_feat, axis=1)
df_cat
# Out:
#        age  hypertension  heart_disease  avg_glucose_level   bmi  stroke  \
# 0    67.00             0              1             228.69 36.60       1
# 2    80.00             0              1             105.92 32.50       1
# 3    49.00             0              0             171.23 34.40       1
# 4    79.00             1              0             174.12 24.00       1
# 5    81.00             0              0             186.21 29.00       1
# ...    ...           ...            ...                ...   ...     ...
# 5104 13.00             0              0             103.08 18.60       0
# 5106 81.00             0              0             125.20 40.00       0
# 5107 35.00             0              0              82.99 30.60       0
# 5108 51.00             0              0             166.29 25.60       0
# 5109 44.00             0              0              85.28 26.20       0
#
#       gender_encoded  ever_married_encoded  work_type_encoded  \
# 0                  1                     1                  2
# 2                  1                     1                  2
# 3                  0                     1                  2
# 4                  0                     1                  3
# 5                  1                     1                  2
# ...              ...                   ...                ...
# 5104               0                     0                  4
# 5106               0                     1                  3
# 5107               0                     1                  3
# 5108               1                     1                  2
# 5109               0                     1                  0
#
#       Residence_type_encoded  smoking_status_encoded
# 0                          1                       1
# 2                          0                       2
# 3                          1                       3
# 4                          0                       2
# 5                          1                       1
# ...                      ...                     ...
# 5104                       0                       0
# 5106                       1                       2
# 5107                       0                       2
# 5108                       0                       1
# 5109                       1                       0
#
# [4909 rows x 11 columns]

# %% [markdown]
# # Split the data up into the features (X) and the target (y)

# %%
X = df_cat.drop('stroke',axis=1)
y = df_cat.stroke.values.reshape(-1,1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
y_train, y_test = y_train.ravel(), y_test.ravel()

# %% [markdown]
# # Used Lazy Classifier to test out various binary classification machine learning models and sorted them by accuracy and F1 score

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
models = models.reset_index()
models = models.sort_values(['Accuracy','F1 Score'], ascending=False)
models
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 29/29 [00:03<00:00,  8.54it/s]
#                             Model  Accuracy  Balanced Accuracy  ROC AUC  \
# 8               BaggingClassifier      0.95               0.54     0.54
# 13         RandomForestClassifier      0.95               0.51     0.51
# 17              RidgeClassifierCV      0.95               0.50     0.50
# 18                  SGDClassifier      0.95               0.50     0.50
# 19                            SVC      0.95               0.50     0.50
# 20                      LinearSVC      0.95               0.50     0.50
# 21                RidgeClassifier      0.95               0.50     0.50
# 22             LogisticRegression      0.95               0.50     0.50
# 23         CalibratedClassifierCV      0.95               0.50     0.50
# 24             AdaBoostClassifier      0.95               0.50     0.50
# 15           KNeighborsClassifier      0.95               0.51     0.51
# 10                 LGBMClassifier      0.95               0.52     0.52
# 16           ExtraTreesClassifier      0.95               0.50     0.50
# 11                  XGBClassifier      0.95               0.51     0.51
# 9      LinearDiscriminantAnalysis      0.94               0.53     0.53
# 12                    BernoulliNB      0.94               0.51     0.51
# 14                     Perceptron      0.94               0.51     0.51
# 4     PassiveAggressiveClassifier      0.93               0.57     0.57
# 6                  LabelSpreading      0.92               0.54     0.54
# 7                LabelPropagation      0.92               0.54     0.54
# 3             ExtraTreeClassifier      0.92               0.59     0.59
# 25                DummyClassifier      0.91               0.50     0.50
# 5          DecisionTreeClassifier      0.91               0.55     0.55
# 2   QuadraticDiscriminantAnalysis      0.88               0.66     0.66
# 1                      GaussianNB      0.87               0.68     0.68
# 0                 NearestCentroid      0.78               0.78     0.78
#
#     F1 Score  Time Taken
# 8       0.93        0.07
# 13      0.93        0.36
# 17      0.93        0.02
# 18      0.93        0.02
# 19      0.93        0.14
# 20      0.93        0.12
# 21      0.93        0.02
# 22      0.93        0.03
# 23      0.93        0.42
# 24      0.93        0.18
# 15      0.93        0.13
# 10      0.93        0.12
# 16      0.93        0.29
# 11      0.93        0.17
# 9       0.93        0.02
# 12      0.92        0.03
# 14      0.92        0.02
# 4       0.92        0.02
# 6       0.92        0.59
# 7       0.92        0.45
# 3       0.92        0.02
# 25      0.91        0.02
# 5       0.91        0.03
# 2       0.90        0.02
# 1       0.90        0.02
# 0       0.84        0.02

# %% [markdown]
# # Build a Sci-Kit pipeline with a standard scaler and using the random forest classifier as a model.
# # Used Gridsearch with cross validation to find the most optimal model for this classifier
# # Explored the results in a DataFrame

# %%
pipe = Pipeline([
    ('scaler',StandardScaler()),
    ('model',RandomForestClassifier())
    ])

mod = GridSearchCV(
                estimator=pipe,
                param_grid={
                    'model__n_estimators':np.arange(1,50,1),
                    'model__max_depth':np.arange(2,15),
                    'model__max_features':['auto', 'sqrt'],
                    'model__min_samples_split':np.arange(2,20),
                    'model__bootstrap':[True, False]
                },
                cv = 5, 
                verbose = 1,
                n_jobs = -1)
mod.fit(X,y)

pd.DataFrame(mod.cv_results_)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# Fitting 5 folds for each of 45864 candidates, totalling 229320 fits
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 668 tasks      | elapsed:   16.0s
# [Parallel(n_jobs=-1)]: Done 1668 tasks      | elapsed:   36.8s
# [Parallel(n_jobs=-1)]: Done 3068 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 4868 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 7068 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 9668 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 12668 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 16068 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done 19868 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done 24068 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done 28668 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done 33668 tasks      | elapsed: 12.3min
# [Parallel(n_jobs=-1)]: Done 39068 tasks      | elapsed: 14.5min
# [Parallel(n_jobs=-1)]: Done 44868 tasks      | elapsed: 16.9min
# [Parallel(n_jobs=-1)]: Done 51068 tasks      | elapsed: 19.7min
# [Parallel(n_jobs=-1)]: Done 57592 tasks      | elapsed: 23.1min
# [Parallel(n_jobs=-1)]: Done 64592 tasks      | elapsed: 26.5min
# [Parallel(n_jobs=-1)]: Done 71808 tasks      | elapsed: 30.3min
# [Parallel(n_jobs=-1)]: Done 76964 tasks      | elapsed: 33.4min
# [Parallel(n_jobs=-1)]: Done 84258 tasks      | elapsed: 37.7min
# [Parallel(n_jobs=-1)]: Done 90532 tasks      | elapsed: 41.2min
# [Parallel(n_jobs=-1)]: Done 96596 tasks      | elapsed: 44.8min
# [Parallel(n_jobs=-1)]: Done 105508 tasks      | elapsed: 49.9min
# [Parallel(n_jobs=-1)]: Done 114244 tasks      | elapsed: 55.0min
# [Parallel(n_jobs=-1)]: Done 123208 tasks      | elapsed: 58.5min
# [Parallel(n_jobs=-1)]: Done 133808 tasks      | elapsed: 63.2min
# [Parallel(n_jobs=-1)]: Done 144660 tasks      | elapsed: 68.2min
# [Parallel(n_jobs=-1)]: Done 154900 tasks      | elapsed: 73.7min
# [Parallel(n_jobs=-1)]: Done 165368 tasks      | elapsed: 79.9min
# [Parallel(n_jobs=-1)]: Done 175508 tasks      | elapsed: 86.1min
# [Parallel(n_jobs=-1)]: Done 182460 tasks      | elapsed: 91.1min
# [Parallel(n_jobs=-1)]: Done 192548 tasks      | elapsed: 97.3min
# [Parallel(n_jobs=-1)]: Done 205948 tasks      | elapsed: 104.8min
# [Parallel(n_jobs=-1)]: Done 219748 tasks      | elapsed: 112.7min
# [Parallel(n_jobs=-1)]: Done 229320 out of 229320 | elapsed: 118.2min finished
#        mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0               0.01          0.00             0.00            0.00
# 1               0.02          0.00             0.00            0.00
# 2               0.02          0.00             0.00            0.00
# 3               0.02          0.00             0.00            0.00
# 4               0.02          0.00             0.00            0.00
# ...              ...           ...              ...             ...
# 45859           0.21          0.00             0.01            0.00
# 45860           0.22          0.00             0.01            0.00
# 45861           0.22          0.00             0.01            0.00
# 45862           0.23          0.01             0.01            0.00
# 45863           0.23          0.00             0.01            0.00
#
#       param_model__bootstrap param_model__max_depth param_model__max_features  \
# 0                       True                      2                      auto
# 1                       True                      2                      auto
# 2                       True                      2                      auto
# 3                       True                      2                      auto
# 4                       True                      2                      auto
# ...                      ...                    ...                       ...
# 45859                  False                     14                      sqrt
# 45860                  False                     14                      sqrt
# 45861                  False                     14                      sqrt
# 45862                  False                     14                      sqrt
# 45863                  False                     14                      sqrt
#
#       param_model__min_samples_split param_model__n_estimators  \
# 0                                  2                         1
# 1                                  2                         2
# 2                                  2                         3
# 3                                  2                         4
# 4                                  2                         5
# ...                              ...                       ...
# 45859                             19                        45
# 45860                             19                        46
# 45861                             19                        47
# 45862                             19                        48
# 45863                             19                        49
#
#                                                   params  split0_test_score  \
# 0      {'model__bootstrap': True, 'model__max_depth':...               0.96
# 1      {'model__bootstrap': True, 'model__max_depth':...               0.96
# 2      {'model__bootstrap': True, 'model__max_depth':...               0.96
# 3      {'model__bootstrap': True, 'model__max_depth':...               0.96
# 4      {'model__bootstrap': True, 'model__max_depth':...               0.96
# ...                                                  ...                ...
# 45859  {'model__bootstrap': False, 'model__max_depth'...               0.96
# 45860  {'model__bootstrap': False, 'model__max_depth'...               0.96
# 45861  {'model__bootstrap': False, 'model__max_depth'...               0.96
# 45862  {'model__bootstrap': False, 'model__max_depth'...               0.96
# 45863  {'model__bootstrap': False, 'model__max_depth'...               0.96
#
#        split1_test_score  split2_test_score  split3_test_score  \
# 0                   0.96               0.96               0.96
# 1                   0.96               0.96               0.96
# 2                   0.96               0.96               0.96
# 3                   0.96               0.96               0.96
# 4                   0.96               0.96               0.96
# ...                  ...                ...                ...
# 45859               0.96               0.96               0.96
# 45860               0.96               0.96               0.96
# 45861               0.96               0.96               0.95
# 45862               0.96               0.96               0.96
# 45863               0.96               0.96               0.96
#
#        split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                   0.96             0.96            0.00            25168
# 1                   0.96             0.96            0.00             1907
# 2                   0.96             0.96            0.00             1907
# 3                   0.96             0.96            0.00             1907
# 4                   0.96             0.96            0.00             1907
# ...                  ...              ...             ...              ...
# 45859               0.96             0.96            0.00            19026
# 45860               0.96             0.96            0.00            31431
# 45861               0.96             0.96            0.00            34577
# 45862               0.96             0.96            0.00            31431
# 45863               0.96             0.96            0.00            27514
#
# [45864 rows x 18 columns]

# %% [markdown]
# # Finding the best model and viewing its accuracy as well as saving the model as a pkl file

# %%
best_etimator = mod.best_estimator_
print(best_etimator)
preds = best_etimator.predict(X_test)
print(accuracy_score(y_test, preds))

file_path = os.path.join('..','models','random_forest_clf_cat.pkl')
joblib.dump(mod.best_estimator_, file_path, compress = 1)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('model',
#                  RandomForestClassifier(max_depth=11, max_features='sqrt',
#                                         min_samples_split=5,
#                                         n_estimators=25))])
# 0.9654320987654321
# ['..\\models\\random_forest_clf_cat.pkl']
